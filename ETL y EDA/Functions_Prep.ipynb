# %% [markdown]
# # Preparación de los Datasets para las funciones

# %%
import pandas as pd
import herramientas as h
import warnings

# %% [markdown]
# Empezamos por filtrar las advertencias para que el código quede más prolijo

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# # PlayTimeGenre

# %% [markdown]
# Importamos los datasets que necesitaremos en dataframes

# %%
steam_games = pd.read_csv('output_steam_games.csv')
user_items = pd.read_csv('australian_users_items.csv')

# %% [markdown]
# Filtramos las columnas de steam_games que necesitaremos

# %%
steam_games = steam_games[['id', 'genres', 'release_date']]

# %% [markdown]
# Filtramos valores 'No data'

# %%
steam_games = steam_games[(steam_games['genres'] != 'No data')]

# %%
steam_games = steam_games[(steam_games['release_date'] != 'No data')]

# %%
steam_games
# Out:
#            id                                             genres release_date
# 0      761140  ['Action', 'Casual', 'Indie', 'Simulation', 'S...   2018-01-04
# 1      643980       ['Free to Play', 'Indie', 'RPG', 'Strategy']   2018-01-04
# 2      670290  ['Casual', 'Free to Play', 'Indie', 'Simulatio...   2017-07-24
# 3      767400                  ['Action', 'Adventure', 'Casual']   2017-12-07
# 5      772540              ['Action', 'Adventure', 'Simulation']   2018-01-04
# ...       ...                                                ...          ...
# 32126  745400         ['Action', 'Adventure', 'Casual', 'Indie']   2018-01-04
# 32127  773640      ['Casual', 'Indie', 'Simulation', 'Strategy']   2018-01-04
# 32128  733530                    ['Casual', 'Indie', 'Strategy']   2018-01-04
# 32129  610660                  ['Indie', 'Racing', 'Simulation']   2018-01-04
# 32130  658870                                ['Casual', 'Indie']   2017-09-02
#
# [28832 rows x 3 columns]

# %% [markdown]
# Creamos la columna 'release_year' extrayendo solo el año de 'release_date' para mayor comodidad y eliminamos la columna 'release_date' y los nulos que vayan quedando en el camino

# %%
steam_games["release_year"] = steam_games["release_date"].str[:4]

# %%
steam_games.drop('release_date', axis=1, inplace=True)

# %%
steam_games["release_year"] = pd.to_numeric(steam_games["release_year"], errors='coerce')

# %%
h.data_info(steam_games)
# Out:
# Total rows:  28832
#
# Total full null rows:  0
#
# Total duplicated rows: 1
#          Column              dType  No_Null_%  No_Null_Qty  Null_%  Null_Qty
# 0            id    [<class 'int'>]     100.00        28832    0.00         0
# 1        genres    [<class 'str'>]     100.00        28832    0.00         0
# 2  release_year  [<class 'float'>]      99.18        28596    0.82       236

# %%
steam_games.dropna(inplace=True)

# %% [markdown]
# Convertimos la columna 'release_year' a tipo entero

# %%
steam_games['release_year'] = steam_games['release_year'].astype(int)

# %%
steam_games = steam_games.reset_index(drop=True)

# %%
steam_games
# Out:
#            id                                             genres  release_year
# 0      761140  ['Action', 'Casual', 'Indie', 'Simulation', 'S...          2018
# 1      643980       ['Free to Play', 'Indie', 'RPG', 'Strategy']          2018
# 2      670290  ['Casual', 'Free to Play', 'Indie', 'Simulatio...          2017
# 3      767400                  ['Action', 'Adventure', 'Casual']          2017
# 4      772540              ['Action', 'Adventure', 'Simulation']          2018
# ...       ...                                                ...           ...
# 28591  745400         ['Action', 'Adventure', 'Casual', 'Indie']          2018
# 28592  773640      ['Casual', 'Indie', 'Simulation', 'Strategy']          2018
# 28593  733530                    ['Casual', 'Indie', 'Strategy']          2018
# 28594  610660                  ['Indie', 'Racing', 'Simulation']          2018
# 28595  658870                                ['Casual', 'Indie']          2017
#
# [28596 rows x 3 columns]

# %%
df = pd.merge(user_items, steam_games, left_on='item_id', right_on='id')

# %%
df
# Out:
#                    user_id  items_count           steam_id
# 0        76561197970982479          277  76561197970982479  \
# 1                  js41637          888  76561198035864385
# 2               Riot-Punch          328  76561197963445855
# 3                    doctr          541  76561198002099482
# 4           corrupted_soul          115  76561198007659921
# ...                    ...          ...                ...
# 4125944       peter1023199           59  76561198060504260
# 4125945  76561198071808318           10  76561198071808318
# 4125946  76561198081168593           84  76561198081168593
# 4125947  76561198107283457           33  76561198107283457
# 4125948              inven         3603  76561198119803063
#
#                                                   user_url  item_id
# 0        http://steamcommunity.com/profiles/76561197970...       10  \
# 1                     http://steamcommunity.com/id/js41637       10
# 2                  http://steamcommunity.com/id/Riot-Punch       10
# 3                       http://steamcommunity.com/id/doctr       10
# 4              http://steamcommunity.com/id/corrupted_soul       10
# ...                                                    ...      ...
# 4125944          http://steamcommunity.com/id/peter1023199   456780
# 4125945  http://steamcommunity.com/profiles/76561198071...   444770
# 4125946  http://steamcommunity.com/profiles/76561198081...   375450
# 4125947  http://steamcommunity.com/profiles/76561198107...   354280
# 4125948                 http://steamcommunity.com/id/inven   433920
#
#                                             item_name  playtime_forever
# 0                                      Counter-Strike                 6  \
# 1                                      Counter-Strike                 0
# 2                                      Counter-Strike                 0
# 3                                      Counter-Strike                93
# 4                                      Counter-Strike               108
# ...                                               ...               ...
# 4125944                     DUCATI - 90th Anniversary                 6
# 4125945                                  Mimpi Dreams                46
# 4125946  NOBUNAGA'S AMBITION: Souzou SengokuRisshiden                51
# 4125947                                    ChaosTower               164
# 4125948                 Aveyond 4: Shadow Of The Mist                 0
#
#          playtime_2weeks      id                                       genres
# 0                      0      10                                   ['Action']  \
# 1                      0      10                                   ['Action']
# 2                      0      10                                   ['Action']
# 3                      0      10                                   ['Action']
# 4                      0      10                                   ['Action']
# ...                  ...     ...                                          ...
# 4125944                0  456780           ['Racing', 'Simulation', 'Sports']
# 4125945                0  444770                       ['Adventure', 'Indie']
# 4125946                0  375450                                 ['Strategy']
# 4125947                0  354280  ['Action', 'Casual', 'Indie', 'Simulation']
# 4125948                0  433920                ['Adventure', 'Indie', 'RPG']
#
#          release_year
# 0                2000
# 1                2000
# 2                2000
# 3                2000
# 4                2000
# ...               ...
# 4125944          2016
# 4125945          2016
# 4125946          2016
# 4125947          2016
# 4125948          2016
#
# [4125949 rows x 11 columns]

# %%
df_playtimegenre = df

# %% [markdown]
# Filtramos las columnas necesarias

# %%
df_playtimegenre = df_playtimegenre[['genres', 'release_year', 'playtime_forever']]

# %%
df_playtimegenre
# Out:
#                                               genres  release_year
# 0                                         ['Action']          2000  \
# 1                                         ['Action']          2000
# 2                                         ['Action']          2000
# 3                                         ['Action']          2000
# 4                                         ['Action']          2000
# ...                                              ...           ...
# 4125944           ['Racing', 'Simulation', 'Sports']          2016
# 4125945                       ['Adventure', 'Indie']          2016
# 4125946                                 ['Strategy']          2016
# 4125947  ['Action', 'Casual', 'Indie', 'Simulation']          2016
# 4125948                ['Adventure', 'Indie', 'RPG']          2016
#
#          playtime_forever
# 0                       6
# 1                       0
# 2                       0
# 3                      93
# 4                     108
# ...                   ...
# 4125944                 6
# 4125945                46
# 4125946                51
# 4125947               164
# 4125948                 0
#
# [4125949 rows x 3 columns]

# %% [markdown]
# Convertimos la columna 'genres' en listas y utilizamos explode. Luego finalmente utilizamos groupby para generar un Dataframe para cumplir de manera más sencilla con la consigna

# %%
df_playtimegenre['genres'] = df_playtimegenre['genres'].apply(eval)

# %%
df_playtimegenre = df_playtimegenre.explode('genres')

# %%
df_playtimegenre
# Out:
#              genres  release_year  playtime_forever
# 0            Action          2000                 6
# 1            Action          2000                 0
# 2            Action          2000                 0
# 3            Action          2000                93
# 4            Action          2000               108
# ...             ...           ...               ...
# 4125947       Indie          2016               164
# 4125947  Simulation          2016               164
# 4125948   Adventure          2016                 0
# 4125948       Indie          2016                 0
# 4125948         RPG          2016                 0
#
# [9805136 rows x 3 columns]

# %%
grouped_df = df_playtimegenre.groupby(['genres', 'release_year'])['playtime_forever'].sum().reset_index()

# %%
grouped_df
# Out:
#              genres  release_year  playtime_forever
# 0            Action          1983              3473
# 1            Action          1984               384
# 2            Action          1988             16001
# 3            Action          1989               607
# 4            Action          1990             18335
# ..              ...           ...               ...
# 338  Web Publishing          2013            333678
# 339  Web Publishing          2014             33641
# 340  Web Publishing          2015            348673
# 341  Web Publishing          2016               136
# 342  Web Publishing          2017              9382
#
# [343 rows x 3 columns]

# %%
df_playtimegenre = grouped_df

# %% [markdown]
# Reemplazamos '&amp' por '&'

# %%
df_playtimegenre['genres'] = df_playtimegenre['genres'].str.replace('&amp;', '&')

# %% [markdown]
# Guardamos el Dataframe en formato CSV

# %%
df_playtimegenre.to_csv('PlayTimeGenre.csv', index=False)

# %% [markdown]
# # UserForGenre

# %% [markdown]
# Importamos los datasets que necesitaremos y hacemos un merge

# %%
steam_games = pd.read_csv('output_steam_games.csv')
user_items = pd.read_csv('australian_users_items.csv')

# %%
df = pd.merge(user_items, steam_games, left_on='item_id', right_on='id')

# %%
df
# Out:
#                    user_id  items_count           steam_id
# 0        76561197970982479          277  76561197970982479  \
# 1                  js41637          888  76561198035864385
# 2               Riot-Punch          328  76561197963445855
# 3                    doctr          541  76561198002099482
# 4           corrupted_soul          115  76561198007659921
# ...                    ...          ...                ...
# 4244826  76561198081168593           84  76561198081168593
# 4244827  76561198101994484          139  76561198101994484
# 4244828  76561198107283457           33  76561198107283457
# 4244829              inven         3603  76561198119803063
# 4244830       danebuchanan          140  76561198190794628
#
#                                                   user_url  item_id
# 0        http://steamcommunity.com/profiles/76561197970...       10  \
# 1                     http://steamcommunity.com/id/js41637       10
# 2                  http://steamcommunity.com/id/Riot-Punch       10
# 3                       http://steamcommunity.com/id/doctr       10
# 4              http://steamcommunity.com/id/corrupted_soul       10
# ...                                                    ...      ...
# 4244826  http://steamcommunity.com/profiles/76561198081...   375450
# 4244827  http://steamcommunity.com/profiles/76561198101...   353390
# 4244828  http://steamcommunity.com/profiles/76561198107...   354280
# 4244829                 http://steamcommunity.com/id/inven   433920
# 4244830          http://steamcommunity.com/id/danebuchanan   485270
#
#                                             item_name  playtime_forever
# 0                                      Counter-Strike                 6  \
# 1                                      Counter-Strike                 0
# 2                                      Counter-Strike                 0
# 3                                      Counter-Strike                93
# 4                                      Counter-Strike               108
# ...                                               ...               ...
# 4244826  NOBUNAGA'S AMBITION: Souzou SengokuRisshiden                51
# 4244827                       Alienware Steam Machine                 0
# 4244828                                    ChaosTower               164
# 4244829                 Aveyond 4: Shadow Of The Mist                 0
# 4244830                                 Arachnophobia                 7
#
#          playtime_2weeks                   publisher
# 0                      0                       Valve  \
# 1                      0                       Valve
# 2                      0                       Valve
# 3                      0                       Valve
# 4                      0                       Valve
# ...                  ...                         ...
# 4244826                0  KOEI TECMO GAMES CO., LTD.
# 4244827                0                     No data
# 4244828                0                CashcowGames
# 4244829                0                      Degica
# 4244830                0                     No data
#
#                                               genres
# 0                                         ['Action']  \
# 1                                         ['Action']
# 2                                         ['Action']
# 3                                         ['Action']
# 4                                         ['Action']
# ...                                              ...
# 4244826                                 ['Strategy']
# 4244827                                      No data
# 4244828  ['Action', 'Casual', 'Indie', 'Simulation']
# 4244829                ['Adventure', 'Indie', 'RPG']
# 4244830                                      No data
#
#                                                   app_name
# 0                                           Counter-Strike  \
# 1                                           Counter-Strike
# 2                                           Counter-Strike
# 3                                           Counter-Strike
# 4                                           Counter-Strike
# ...                                                    ...
# 4244826  NOBUNAGA'S AMBITION: Sphere of Influence - Asc...
# 4244827                            Alienware Steam Machine
# 4244828                                         ChaosTower
# 4244829                      Aveyond 4: Shadow of the Mist
# 4244830                                      Arachnophobia
#
#                                                        url release_date
# 0        http://store.steampowered.com/app/10/CounterSt...   2000-11-01  \
# 1        http://store.steampowered.com/app/10/CounterSt...   2000-11-01
# 2        http://store.steampowered.com/app/10/CounterSt...   2000-11-01
# 3        http://store.steampowered.com/app/10/CounterSt...   2000-11-01
# 4        http://store.steampowered.com/app/10/CounterSt...   2000-11-01
# ...                                                    ...          ...
# 4244826  http://store.steampowered.com/app/375450/NOBUN...   2016-03-23
# 4244827  http://store.steampowered.com/app/353390/Alien...   2015-11-10
# 4244828  http://store.steampowered.com/app/354280/Chaos...   2016-02-23
# 4244829  http://store.steampowered.com/app/433920/Aveyo...   2016-02-01
# 4244830  http://store.steampowered.com/app/485270/Arach...      No data
#
#                                                       tags
# 0        ['Action', 'FPS', 'Multiplayer', 'Shooter', 'C...  \
# 1        ['Action', 'FPS', 'Multiplayer', 'Shooter', 'C...
# 2        ['Action', 'FPS', 'Multiplayer', 'Shooter', 'C...
# 3        ['Action', 'FPS', 'Multiplayer', 'Shooter', 'C...
# 4        ['Action', 'FPS', 'Multiplayer', 'Shooter', 'C...
# ...                                                    ...
# 4244826                         ['Strategy', 'Historical']
# 4244827  ['Steam Machine', 'Hardware', 'Gaming', 'Futur...
# 4244828        ['Indie', 'Casual', 'Action', 'Simulation']
# 4244829          ['RPG', 'Indie', 'Adventure', 'RPGMaker']
# 4244830  ['Casual', 'Simulation', 'Psychological Horror...
#
#                                                reviews_url
# 0        http://steamcommunity.com/app/10/reviews/?brow...  \
# 1        http://steamcommunity.com/app/10/reviews/?brow...
# 2        http://steamcommunity.com/app/10/reviews/?brow...
# 3        http://steamcommunity.com/app/10/reviews/?brow...
# 4        http://steamcommunity.com/app/10/reviews/?brow...
# ...                                                    ...
# 4244826  http://steamcommunity.com/app/375450/reviews/?...
# 4244827  http://steamcommunity.com/app/353390/reviews/?...
# 4244828  http://steamcommunity.com/app/354280/reviews/?...
# 4244829  http://steamcommunity.com/app/433920/reviews/?...
# 4244830  http://steamcommunity.com/app/485270/reviews/?...
#
#                                                      specs   price
# 0             ['Multi-player', 'Valve Anti-Cheat enabled']    9.99  \
# 1             ['Multi-player', 'Valve Anti-Cheat enabled']    9.99
# 2             ['Multi-player', 'Valve Anti-Cheat enabled']    9.99
# 3             ['Multi-player', 'Valve Anti-Cheat enabled']    9.99
# 4             ['Multi-player', 'Valve Anti-Cheat enabled']    9.99
# ...                                                    ...     ...
# 4244826  ['Single-player', 'Steam Achievements', 'Steam...   59.99
# 4244827                                            No data  449.00
# 4244828  ['Single-player', 'Steam Achievements', 'Steam...    5.99
# 4244829                                  ['Single-player']   14.99
# 4244830  ['Single-player', 'HTC Vive', 'Oculus Rift', '...    4.99
#
#          early_access      id                   developer
# 0               False      10                       Valve
# 1               False      10                       Valve
# 2               False      10                       Valve
# 3               False      10                       Valve
# 4               False      10                       Valve
# ...               ...     ...                         ...
# 4244826         False  375450  KOEI TECMO GAMES CO., LTD.
# 4244827         False  353390                     No data
# 4244828         False  354280                CashcowGames
# 4244829         False  433920         Amaranth Games, LLC
# 4244830         False  485270                     No data
#
# [4244831 rows x 20 columns]

# %% [markdown]
# Filtramos las columnas necesarias y eliminamos los valores "No data"

# %%
df_userforgenre = df[['user_id', 'genres', 'release_date', 'playtime_forever']]

# %%
df_userforgenre = df_userforgenre[(df_userforgenre['genres'] != 'No data')]

# %%
df_userforgenre = df_userforgenre[(df_userforgenre['release_date'] != 'No data')]

# %%
df_userforgenre
# Out:
#                    user_id                                       genres
# 0        76561197970982479                                   ['Action']  \
# 1                  js41637                                   ['Action']
# 2               Riot-Punch                                   ['Action']
# 3                    doctr                                   ['Action']
# 4           corrupted_soul                                   ['Action']
# ...                    ...                                          ...
# 4244824       peter1023199           ['Racing', 'Simulation', 'Sports']
# 4244825  76561198071808318                       ['Adventure', 'Indie']
# 4244826  76561198081168593                                 ['Strategy']
# 4244828  76561198107283457  ['Action', 'Casual', 'Indie', 'Simulation']
# 4244829              inven                ['Adventure', 'Indie', 'RPG']
#
#         release_date  playtime_forever
# 0         2000-11-01                 6
# 1         2000-11-01                 0
# 2         2000-11-01                 0
# 3         2000-11-01                93
# 4         2000-11-01               108
# ...              ...               ...
# 4244824   2016-06-09                 6
# 4244825   2016-03-22                46
# 4244826   2016-03-23                51
# 4244828   2016-02-23               164
# 4244829   2016-02-01                 0
#
# [4149883 rows x 4 columns]

# %% [markdown]
# Creamos una nueva columna llamada "release_year" quedandonos únicamente con el año de "release_date" para mayor comodidad y filtramos errores o valores nulos que vayan quedando en el camino

# %%
df_userforgenre["release_year"] = df_userforgenre["release_date"].str[:4]

# %%
df_userforgenre.drop('release_date', axis=1, inplace=True)

# %%
df_userforgenre
# Out:
#                    user_id                                       genres
# 0        76561197970982479                                   ['Action']  \
# 1                  js41637                                   ['Action']
# 2               Riot-Punch                                   ['Action']
# 3                    doctr                                   ['Action']
# 4           corrupted_soul                                   ['Action']
# ...                    ...                                          ...
# 4244824       peter1023199           ['Racing', 'Simulation', 'Sports']
# 4244825  76561198071808318                       ['Adventure', 'Indie']
# 4244826  76561198081168593                                 ['Strategy']
# 4244828  76561198107283457  ['Action', 'Casual', 'Indie', 'Simulation']
# 4244829              inven                ['Adventure', 'Indie', 'RPG']
#
#          playtime_forever release_year
# 0                       6         2000
# 1                       0         2000
# 2                       0         2000
# 3                      93         2000
# 4                     108         2000
# ...                   ...          ...
# 4244824                 6         2016
# 4244825                46         2016
# 4244826                51         2016
# 4244828               164         2016
# 4244829                 0         2016
#
# [4149883 rows x 4 columns]

# %%
df_userforgenre["release_year"] = pd.to_numeric(df_userforgenre["release_year"], errors='coerce')

# %%
h.data_info(df_userforgenre)
# Out:
# Total rows:  4149883
#
# Total full null rows:  0
#
# Total duplicated rows: 329965
#              Column              dType  No_Null_%  No_Null_Qty  Null_%
# 0           user_id    [<class 'str'>]     100.00      4149883    0.00  \
# 1            genres    [<class 'str'>]     100.00      4149883    0.00
# 2  playtime_forever    [<class 'int'>]     100.00      4149883    0.00
# 3      release_year  [<class 'float'>]      99.42      4125949    0.58
#
#    Null_Qty
# 0         0
# 1         0
# 2         0
# 3     23934

# %%
df_userforgenre.dropna(inplace=True)

# %%
h.data_info(df_userforgenre)
# Out:
# Total rows:  4125949
#
# Total full null rows:  0
#
# Total duplicated rows: 329798
#              Column              dType  No_Null_%  No_Null_Qty  Null_%
# 0           user_id    [<class 'str'>]      100.0      4125949     0.0  \
# 1            genres    [<class 'str'>]      100.0      4125949     0.0
# 2  playtime_forever    [<class 'int'>]      100.0      4125949     0.0
# 3      release_year  [<class 'float'>]      100.0      4125949     0.0
#
#    Null_Qty
# 0         0
# 1         0
# 2         0
# 3         0

# %%
df_userforgenre['release_year'] = df_userforgenre['release_year'].astype(int)

# %%
df_userforgenre
# Out:
#                    user_id                                       genres
# 0        76561197970982479                                   ['Action']  \
# 1                  js41637                                   ['Action']
# 2               Riot-Punch                                   ['Action']
# 3                    doctr                                   ['Action']
# 4           corrupted_soul                                   ['Action']
# ...                    ...                                          ...
# 4244824       peter1023199           ['Racing', 'Simulation', 'Sports']
# 4244825  76561198071808318                       ['Adventure', 'Indie']
# 4244826  76561198081168593                                 ['Strategy']
# 4244828  76561198107283457  ['Action', 'Casual', 'Indie', 'Simulation']
# 4244829              inven                ['Adventure', 'Indie', 'RPG']
#
#          playtime_forever  release_year
# 0                       6          2000
# 1                       0          2000
# 2                       0          2000
# 3                      93          2000
# 4                     108          2000
# ...                   ...           ...
# 4244824                 6          2016
# 4244825                46          2016
# 4244826                51          2016
# 4244828               164          2016
# 4244829                 0          2016
#
# [4125949 rows x 4 columns]

# %% [markdown]
# Convertimos la columna "genres" en listas y utilizamos explode. Luego finalmente utilizamos groupby para agrupar los datos para generar un dataset para cumplir con la consigna.

# %%
df_userforgenre['genres'] = df_userforgenre['genres'].apply(eval)

# %%
df_userforgenre = df_userforgenre.explode('genres')

# %%
df_userforgenre
# Out:
#                    user_id      genres  playtime_forever  release_year
# 0        76561197970982479      Action                 6          2000
# 1                  js41637      Action                 0          2000
# 2               Riot-Punch      Action                 0          2000
# 3                    doctr      Action                93          2000
# 4           corrupted_soul      Action               108          2000
# ...                    ...         ...               ...           ...
# 4244828  76561198107283457       Indie               164          2016
# 4244828  76561198107283457  Simulation               164          2016
# 4244829              inven   Adventure                 0          2016
# 4244829              inven       Indie                 0          2016
# 4244829              inven         RPG                 0          2016
#
# [9805136 rows x 4 columns]

# %% [markdown]
# Comenzamos a utilizar groupby para obtener un Dataframe con el usuario con más horas jugadas por cada género

# %%
grouped_df = df_userforgenre.groupby(['user_id', 'genres'])['playtime_forever'].sum().reset_index()

# %%
grouped_df
# Out:
#            user_id        genres  playtime_forever
# 0          --000--        Action            139465
# 1          --000--     Adventure             11722
# 2          --000--        Casual             16135
# 3          --000--  Early Access               531
# 4          --000--  Free to Play             20444
# ...            ...           ...               ...
# 670322  zzzmidmiss           RPG              2337
# 670323  zzzmidmiss        Racing                 9
# 670324  zzzmidmiss    Simulation                16
# 670325  zzzmidmiss        Sports               210
# 670326  zzzmidmiss      Strategy              1002
#
# [670327 rows x 3 columns]

# %%
idx_max_playtime = grouped_df.groupby('genres')['playtime_forever'].idxmax()

# %%
result_df = grouped_df.loc[idx_max_playtime]

# %%
result_df
# Out:
#                   user_id                     genres  playtime_forever
# 485519            Sp3ctre                     Action           1692650
# 472192       REBAS_AS_F-T                  Adventure           2182066
# 479391         ScottyG555   Animation &amp; Modeling            168314
# 447836        Lickidactyl           Audio Production            109916
# 472195       REBAS_AS_F-T                     Casual           1224933
# 479393         ScottyG555  Design &amp; Illustration            168314
# 18051   76561197978756659               Early Access            316969
# 160609  76561198059330972                  Education             65427
# 570659         idonothack               Free to Play            808241
# 472200       REBAS_AS_F-T                      Indie           2401378
# 417826        Evilutional      Massively Multiplayer            688260
# 483274           Sky_Wolf              Photo Editing             21885
# 634706        shinomegami                        RPG           1023495
# 412843    DownSyndromeKid                     Racing            743445
# 577998           jimmynoe                 Simulation           1062130
# 447845        Lickidactyl          Software Training            109916
# 26187   76561197995725436                     Sports            193206
# 634711        shinomegami                   Strategy           1104450
# 248243  76561198073642113                  Utilities            207651
# 479403         ScottyG555           Video Production            168314
# 506902            Xyphien             Web Publishing            142964

# %% [markdown]
# Normalizamos los valores "Animation &amp; Modeling" y "Design &amp; Illustration"

# %%
df_userforgenre['genres'] = df_userforgenre['genres'].replace('Animation &amp; Modeling', 'Animation & Modeling')

# %%
df_userforgenre['genres'] = df_userforgenre['genres'].replace('Design &amp; Illustration', 'Design & Illustration')

# %% [markdown]
# Ahora obtenemos un Dataframe con la cantidad total de horas jugadas por usuario, género y año

# %%
df_agrupado = df_userforgenre.groupby(['user_id', 'genres', 'release_year'])['playtime_forever'].sum().reset_index()

# %%
df_userforgenre = df_agrupado

# %%
df_userforgenre
# Out:
#             user_id    genres  release_year  playtime_forever
# 0           --000--    Action          2009              5329
# 1           --000--    Action          2010                22
# 2           --000--    Action          2011              6522
# 3           --000--    Action          2012            109346
# 4           --000--    Action          2013               363
# ...             ...       ...           ...               ...
# 3429398  zzzmidmiss  Strategy          2009                 0
# 3429399  zzzmidmiss  Strategy          2010                10
# 3429400  zzzmidmiss  Strategy          2011                69
# 3429401  zzzmidmiss  Strategy          2012               923
# 3429402  zzzmidmiss  Strategy          2016                 0
#
# [3429403 rows x 4 columns]

# %% [markdown]
# Ahora buscaremos filtrar el Dataframe dejando únicamente los datos del usuario con más horas jugadas por cada género

# %%
combinaciones = [
	('Sp3ctre', 'Action'),
	('REBAS_AS_F-T', 'Adventure'),
	('ScottyG555', 'Animation & Modeling'),
	('Lickidactyl', 'Audio Production'),
	('REBAS_AS_F-T', 'Casual'),
	('ScottyG555', 'Design & Illustration'),
	('76561197978756659', 'Early Access'),
	('76561198059330972', 'Education'),
	('idonothack', 'Free to Play'),
	('REBAS_AS_F-T', 'Indie'),
	('Evilutional', 'Massively Multiplayer'),
	('Sky_Wolf', 'Photo Editing'),
	('shinomegami', 'RPG'),
	('DownSyndromeKid', 'Racing'),
	('jimmynoe', 'Simulation'),
	('Lickidactyl', 'Software Training'),
	('76561197995725436', 'Sports'),
	('shinomegami', 'Strategy'),
	('76561198073642113', 'Utilities'),
	('ScottyG555', 'Video Production'),
	('Xyphien', 'Web Publishing')
]

# %%
df_resultado = pd.DataFrame(columns=df_userforgenre.columns)

# %%
for user_id, genres in combinaciones:
    filtro = (df_userforgenre['user_id'] == user_id) & (df_userforgenre['genres'] == genres)
    df_resultado = pd.concat([df_resultado, df_userforgenre[filtro]])

# %%
df_userforgenre = df_resultado

# %%
df_userforgenre
# Out:
#                    user_id            genres release_year playtime_forever
# 2375701            Sp3ctre            Action         1993                0
# 2375702            Sp3ctre            Action         1995              217
# 2375703            Sp3ctre            Action         1996                0
# 2375704            Sp3ctre            Action         1998                0
# 2375705            Sp3ctre            Action         1999               44
# ...                    ...               ...          ...              ...
# 1231094  76561198073642113         Utilities         2014           207651
# 2339186         ScottyG555  Video Production         2015           168314
# 2501413            Xyphien    Web Publishing         2005             7296
# 2501414            Xyphien    Web Publishing         2012            64657
# 2501415            Xyphien    Web Publishing         2015            71011
#
# [168 rows x 4 columns]

# %% [markdown]
# Filtramos las filas que contengan '0' en la columna 'playtime_forever'

# %%
df_userforgenre = df_userforgenre[(df_userforgenre['playtime_forever'] != 0)]

# %% [markdown]
# Notamos también que la columna 'playtime_forever' está en minutos, por lo que lo convertimos a horas y también convertimos la columna a entero (ya que quedará con valores flotantes). Volvemos a filtrar filas con valores 0 si es que quedaron

# %%
df_userforgenre['playtime_forever'] = df_userforgenre['playtime_forever'] / 60

# %%
df_userforgenre['playtime_forever'] = df_userforgenre['playtime_forever'].astype(int)

# %%
df_userforgenre = df_userforgenre[(df_userforgenre['playtime_forever'] != 0)]

# %% [markdown]
# Finalmente guardamos el Dataframe en formato CSV

# %%
df_userforgenre.to_csv('UserForGenre.csv', index=False)

# %% [markdown]
# # UsersRecommend

# %% [markdown]
# Importamos los Datasets que necesitaremos y hacemos el merge

# %%
user_reviews = pd.read_csv('australian_user_reviews_actualizado.csv')
steam_games = pd.read_csv('output_steam_games.csv')

# %%
df_usersrecommend = pd.merge(user_reviews, steam_games, left_on='item_id', right_on='id')

# %%
df_usersrecommend
# Out:
#                                   funny                    posted
# 0                               No data  Posted November 5, 2011.  \
# 1                               No data    Posted March 30, 2015.
# 2                               No data     Posted July 12, 2013.
# 3                               No data   Posted August 13, 2015.
# 4                               No data     Posted April 5, 2014.
# ...                                 ...                       ...
# 53164                           No data  Posted October 29, 2015.
# 53165                           No data             Posted May 5.
# 53166  1 person found this review funny         Posted August 13.
# 53167                           No data         Posted August 13.
# 53168                           No data           Posted March 5.
#
#                   last_edited  item_id
# 0                     No data     1250  \
# 1                     No data     1250
# 2                     No data     1250
# 3                     No data     1250
# 4                     No data     1250
# ...                       ...      ...
# 53164                 No data   307130
# 53165                 No data   209120
# 53166  Last edited August 13.   220090
# 53167                 No data   262850
# 53168                 No data   431510
#
#                                              helpful  recommend
# 0                                     No ratings yet       True  \
# 1                                     No ratings yet       True
# 2                                     No ratings yet       True
# 3                                     No ratings yet       True
# 4                                     No ratings yet       True
# ...                                              ...        ...
# 53164  1 of 5 people (20%) found this review helpful       True
# 53165  3 of 6 people (50%) found this review helpful       True
# 53166  3 of 6 people (50%) found this review helpful       True
# 53167   0 of 1 people (0%) found this review helpful       True
# 53168  8 of 9 people (89%) found this review helpful       True
#
#                                                   review            user_id
# 0      Simple yet with great replayability. In my opi...  76561197970982479  \
# 1      Amazing, Non-stop action of blowing stuff to b...       death-hunter
# 2      Compared to Left 4 Dead 2, this game REALLY gi...           DJKamBer
# 3                                             Jogo ♥♥♥♥.          diego9031
# 4      cara nas imagens esse jogo da pouco de medo ma...  76561198081962345
# ...                                                  ...                ...
# 53164  Asteria is a fast paced indie platformer, wrap...        llDracuwulf
# 53165   Great game, awkward to get running in windows 10       ChrisCoroner
# 53166  GET THIS GAME AND CHAPTER TWO!!!!!!!!!!!!!!!!!...       MeloncraftLP
# 53167  THIS GAME!!!!!!!!!!!!!!!!!! WOOOOOOOOOOOOOOOOO...       MeloncraftLP
# 53168  Highly recommended! The storyline for shou is ...         vinquility
#
#                                                 user_url  sentiment_analysis
# 0      http://steamcommunity.com/profiles/76561197970...                   2  \
# 1              http://steamcommunity.com/id/death-hunter                   2
# 2                  http://steamcommunity.com/id/DJKamBer                   2
# 3                 http://steamcommunity.com/id/diego9031                   1
# 4      http://steamcommunity.com/profiles/76561198081...                   1
# ...                                                  ...                 ...
# 53164           http://steamcommunity.com/id/llDracuwulf                   2
# 53165          http://steamcommunity.com/id/ChrisCoroner                   0
# 53166          http://steamcommunity.com/id/MeloncraftLP                   0
# 53167          http://steamcommunity.com/id/MeloncraftLP                   0
# 53168            http://steamcommunity.com/id/vinquility                   2
#
#        ...                                app_name
# 0      ...                           Killing Floor  \
# 1      ...                           Killing Floor
# 2      ...                           Killing Floor
# 3      ...                           Killing Floor
# 4      ...                           Killing Floor
# ...    ...                                     ...
# 53164  ...                                 Asteria
# 53165  ...                 Street Fighter X Tekken
# 53166  ...           The Journey Down: Chapter One
# 53167  ...           The Journey Down: Chapter Two
# 53168  ...  Mystic Destinies: Serendipity of Aeons
#
#                                                      url release_date
# 0      http://store.steampowered.com/app/1250/Killing...   2009-05-14  \
# 1      http://store.steampowered.com/app/1250/Killing...   2009-05-14
# 2      http://store.steampowered.com/app/1250/Killing...   2009-05-14
# 3      http://store.steampowered.com/app/1250/Killing...   2009-05-14
# 4      http://store.steampowered.com/app/1250/Killing...   2009-05-14
# ...                                                  ...          ...
# 53164  http://store.steampowered.com/app/307130/Asteria/   2014-07-03
# 53165  http://store.steampowered.com/app/209120/Stree...   2012-05-11
# 53166  http://store.steampowered.com/app/220090/The_J...   2013-01-09
# 53167  http://store.steampowered.com/app/262850/The_J...   2014-08-25
# 53168  http://store.steampowered.com/app/431510/Mysti...   2016-02-11
#
#                                                     tags
# 0      ['FPS', 'Zombies', 'Co-op', 'Survival', 'Actio...  \
# 1      ['FPS', 'Zombies', 'Co-op', 'Survival', 'Actio...
# 2      ['FPS', 'Zombies', 'Co-op', 'Survival', 'Actio...
# 3      ['FPS', 'Zombies', 'Co-op', 'Survival', 'Actio...
# 4      ['FPS', 'Zombies', 'Co-op', 'Survival', 'Actio...
# ...                                                  ...
# 53164  ['Indie', 'Adventure', 'Action', 'Platformer',...
# 53165  ['Fighting', 'Action', 'Arcade', '2D Fighter',...
# 53166  ['Adventure', 'Point & Click', 'Indie', 'Comed...
# 53167  ['Adventure', 'Indie', 'Point & Click', 'Great...
# 53168  ['Visual Novel', 'Otome', 'Female Protagonist'...
#
#                                              reviews_url
# 0      http://steamcommunity.com/app/1250/reviews/?br...  \
# 1      http://steamcommunity.com/app/1250/reviews/?br...
# 2      http://steamcommunity.com/app/1250/reviews/?br...
# 3      http://steamcommunity.com/app/1250/reviews/?br...
# 4      http://steamcommunity.com/app/1250/reviews/?br...
# ...                                                  ...
# 53164  http://steamcommunity.com/app/307130/reviews/?...
# 53165  http://steamcommunity.com/app/209120/reviews/?...
# 53166  http://steamcommunity.com/app/220090/reviews/?...
# 53167  http://steamcommunity.com/app/262850/reviews/?...
# 53168  http://steamcommunity.com/app/431510/reviews/?...
#
#                                                    specs  price early_access
# 0      ['Single-player', 'Multi-player', 'Co-op', 'Cr...  19.99        False  \
# 1      ['Single-player', 'Multi-player', 'Co-op', 'Cr...  19.99        False
# 2      ['Single-player', 'Multi-player', 'Co-op', 'Cr...  19.99        False
# 3      ['Single-player', 'Multi-player', 'Co-op', 'Cr...  19.99        False
# 4      ['Single-player', 'Multi-player', 'Co-op', 'Cr...  19.99        False
# ...                                                  ...    ...          ...
# 53164  ['Single-player', 'Multi-player', 'Co-op', 'St...   4.99        False
# 53165  ['Single-player', 'Multi-player', 'Co-op', 'Sh...  29.99        False
# 53166           ['Single-player', 'Steam Trading Cards']   8.99        False
# 53167           ['Single-player', 'Steam Trading Cards']  19.99        False
# 53168  ['Single-player', 'Steam Achievements', 'Steam...   0.00        False
#
#            id             developer
# 0        1250  Tripwire Interactive
# 1        1250  Tripwire Interactive
# 2        1250  Tripwire Interactive
# 3        1250  Tripwire Interactive
# 4        1250  Tripwire Interactive
# ...       ...                   ...
# 53164  307130         Legend Studio
# 53165  209120   Capcom U.S.A., Inc.
# 53166  220090             SkyGoblin
# 53167  262850             SkyGoblin
# 53168  431510    Aeon Dream Studios
#
# [53169 rows x 22 columns]

# %% [markdown]
# Filtramos las columnas necesarias

# %%
df_usersrecommend = df_usersrecommend[['posted', 'app_name', 'recommend', 'sentiment_analysis']]

# %%
df_usersrecommend
# Out:
#                          posted                                app_name
# 0      Posted November 5, 2011.                           Killing Floor  \
# 1        Posted March 30, 2015.                           Killing Floor
# 2         Posted July 12, 2013.                           Killing Floor
# 3       Posted August 13, 2015.                           Killing Floor
# 4         Posted April 5, 2014.                           Killing Floor
# ...                         ...                                     ...
# 53164  Posted October 29, 2015.                                 Asteria
# 53165             Posted May 5.                 Street Fighter X Tekken
# 53166         Posted August 13.           The Journey Down: Chapter One
# 53167         Posted August 13.           The Journey Down: Chapter Two
# 53168           Posted March 5.  Mystic Destinies: Serendipity of Aeons
#
#        recommend  sentiment_analysis
# 0           True                   2
# 1           True                   2
# 2           True                   2
# 3           True                   1
# 4           True                   1
# ...          ...                 ...
# 53164       True                   2
# 53165       True                   0
# 53166       True                   0
# 53167       True                   0
# 53168       True                   2
#
# [53169 rows x 4 columns]

# %% [markdown]
# Normalizaremos la columna 'posted' y nos quedaremos solo con el año. Para empezar intentaremos extraer el año.

# %%
df = df_usersrecommend

# %%
df['year'] = df['posted'].str.extract(r'(\d{4})')

# %%
df
# Out:
#                          posted                                app_name
# 0      Posted November 5, 2011.                           Killing Floor  \
# 1        Posted March 30, 2015.                           Killing Floor
# 2         Posted July 12, 2013.                           Killing Floor
# 3       Posted August 13, 2015.                           Killing Floor
# 4         Posted April 5, 2014.                           Killing Floor
# ...                         ...                                     ...
# 53164  Posted October 29, 2015.                                 Asteria
# 53165             Posted May 5.                 Street Fighter X Tekken
# 53166         Posted August 13.           The Journey Down: Chapter One
# 53167         Posted August 13.           The Journey Down: Chapter Two
# 53168           Posted March 5.  Mystic Destinies: Serendipity of Aeons
#
#        recommend  sentiment_analysis  year
# 0           True                   2  2011
# 1           True                   2  2015
# 2           True                   2  2013
# 3           True                   1  2015
# 4           True                   1  2014
# ...          ...                 ...   ...
# 53164       True                   2  2015
# 53165       True                   0   NaN
# 53166       True                   0   NaN
# 53167       True                   0   NaN
# 53168       True                   2   NaN
#
# [53169 rows x 5 columns]

# %% [markdown]
# Eliminamos las filas con valores nulos ya que significa que en la columna 'posted' no especificaba un año y también eliminamos la columna 'posted'

# %%
df.dropna(inplace=True)

# %%
df.drop('posted', axis=1, inplace=True)

# %%
df
# Out:
#                   app_name  recommend  sentiment_analysis  year
# 0            Killing Floor       True                   2  2011
# 1            Killing Floor       True                   2  2015
# 2            Killing Floor       True                   2  2013
# 3            Killing Floor       True                   1  2015
# 4            Killing Floor       True                   1  2014
# ...                    ...        ...                 ...   ...
# 53160         Aero's Quest       True                   0  2015
# 53161         Aero's Quest       True                   2  2015
# 53162  Another Perspective      False                   0  2015
# 53163           The Howler       True                   2  2015
# 53164              Asteria       True                   2  2015
#
# [44087 rows x 4 columns]

# %%
h.data_info(df)
# Out:
# Total rows:  44087
#
# Total full null rows:  0
#
# Total duplicated rows: 35629
#                Column             dType  No_Null_%  No_Null_Qty  Null_%
# 0            app_name   [<class 'str'>]      100.0        44087     0.0  \
# 1           recommend  [<class 'bool'>]      100.0        44087     0.0
# 2  sentiment_analysis   [<class 'int'>]      100.0        44087     0.0
# 3                year   [<class 'int'>]      100.0        44087     0.0
#
#    Null_Qty
# 0         0
# 1         0
# 2         0
# 3         0

# %%
df_usersrecommend = df

# %% [markdown]
# Convertimos la columna 'year' a tipo entero

# %%
df_usersrecommend['year'] = df_usersrecommend['year'].astype(int)

# %%
df_usersrecommend
# Out:
#                   app_name  recommend  sentiment_analysis  year
# 0            Killing Floor       True                   2  2011
# 1            Killing Floor       True                   2  2015
# 2            Killing Floor       True                   2  2013
# 3            Killing Floor       True                   1  2015
# 4            Killing Floor       True                   1  2014
# ...                    ...        ...                 ...   ...
# 53160         Aero's Quest       True                   0  2015
# 53161         Aero's Quest       True                   2  2015
# 53162  Another Perspective      False                   0  2015
# 53163           The Howler       True                   2  2015
# 53164              Asteria       True                   2  2015
#
# [44087 rows x 4 columns]

# %% [markdown]
# Filtramos los valores 'False' en la columna 'recommend' y los valores 0 en la columna 'sentiment_analysis'

# %%
df_usersrecommend = df_usersrecommend[(df_usersrecommend['recommend'] != False)]

# %%
df_usersrecommend = df_usersrecommend[(df_usersrecommend['sentiment_analysis'] != 0)]

# %%
df_usersrecommend
# Out:
#             app_name  recommend  sentiment_analysis  year
# 0      Killing Floor       True                   2  2011
# 1      Killing Floor       True                   2  2015
# 2      Killing Floor       True                   2  2013
# 3      Killing Floor       True                   1  2015
# 4      Killing Floor       True                   1  2014
# ...              ...        ...                 ...   ...
# 53158          Pongo       True                   2  2015
# 53159         Millie       True                   1  2015
# 53161   Aero's Quest       True                   2  2015
# 53163     The Howler       True                   2  2015
# 53164        Asteria       True                   2  2015
#
# [32885 rows x 4 columns]

# %% [markdown]
# Eliminamos la columna 'recommend' ya que dejó de ser necesaria

# %%
df_usersrecommend.drop('recommend', axis=1, inplace=True)

# %%
df_usersrecommend
# Out:
#             app_name  sentiment_analysis  year
# 0      Killing Floor                   2  2011
# 1      Killing Floor                   2  2015
# 2      Killing Floor                   2  2013
# 3      Killing Floor                   1  2015
# 4      Killing Floor                   1  2014
# ...              ...                 ...   ...
# 53158          Pongo                   2  2015
# 53159         Millie                   1  2015
# 53161   Aero's Quest                   2  2015
# 53163     The Howler                   2  2015
# 53164        Asteria                   2  2015
#
# [32885 rows x 3 columns]

# %% [markdown]
# Creamos una nueva columna llamada 'recommendations' que sumará los valores de 'sentiment_analysis' por juego y año. Los sumaré para darle mayor peso a aquellos que recibieron una reseña positiva, ya que no es lo mismo una reseña positiva que neutral o nula (recordemos que aquellos juegos que no tienen reseña se les asignó una reseña neutral)

# %%
df_usersrecommend['recommendations'] = df_usersrecommend.groupby(['app_name', 'year'])['sentiment_analysis'].transform('sum')

# %%
df_usersrecommend
# Out:
#             app_name  sentiment_analysis  year  recommendations
# 0      Killing Floor                   2  2011               24
# 1      Killing Floor                   2  2015               48
# 2      Killing Floor                   2  2013              120
# 3      Killing Floor                   1  2015               48
# 4      Killing Floor                   1  2014              184
# ...              ...                 ...   ...              ...
# 53158          Pongo                   2  2015                2
# 53159         Millie                   1  2015                1
# 53161   Aero's Quest                   2  2015                2
# 53163     The Howler                   2  2015                2
# 53164        Asteria                   2  2015                2
#
# [32885 rows x 4 columns]

# %% [markdown]
# Eliminamos duplicados y la columna 'sentiment_analysis'

# %%
df_usersrecommend = df_usersrecommend[['app_name', 'year', 'recommendations']].drop_duplicates()

# %%
df_usersrecommend
# Out:
#             app_name  year  recommendations
# 0      Killing Floor  2011               24
# 1      Killing Floor  2015               48
# 2      Killing Floor  2013              120
# 4      Killing Floor  2014              184
# 5      Killing Floor  2010               11
# ...              ...   ...              ...
# 53158          Pongo  2015                2
# 53159         Millie  2015                1
# 53161   Aero's Quest  2015                2
# 53163     The Howler  2015                2
# 53164        Asteria  2015                2
#
# [3587 rows x 3 columns]

# %% [markdown]
# Le cambiamos el nombre a la columna 'recommendations' por 'recommend_score', ya que es un nombre más adecuado

# %%
df_usersrecommend = df_usersrecommend.rename(columns={'recommendations': 'recommend_score'})

# %% [markdown]
# Guardamos el Dataframe en formato CSV

# %%
df_usersrecommend.to_csv('UsersRecommend.csv', index=False)

# %% [markdown]
# # UsersWorstDeveloper

# %% [markdown]
# Importamos los Datasets que necesitaremos y hacemos el merge

# %%
user_reviews = pd.read_csv('australian_user_reviews_actualizado.csv')
steam_games = pd.read_csv('output_steam_games.csv')

# %%
df_usersworstdeveloper = pd.merge(user_reviews, steam_games, left_on='item_id', right_on='id')

# %%
df_usersworstdeveloper
# Out:
#                                   funny                    posted
# 0                               No data  Posted November 5, 2011.  \
# 1                               No data    Posted March 30, 2015.
# 2                               No data     Posted July 12, 2013.
# 3                               No data   Posted August 13, 2015.
# 4                               No data     Posted April 5, 2014.
# ...                                 ...                       ...
# 53164                           No data  Posted October 29, 2015.
# 53165                           No data             Posted May 5.
# 53166  1 person found this review funny         Posted August 13.
# 53167                           No data         Posted August 13.
# 53168                           No data           Posted March 5.
#
#                   last_edited  item_id
# 0                     No data     1250  \
# 1                     No data     1250
# 2                     No data     1250
# 3                     No data     1250
# 4                     No data     1250
# ...                       ...      ...
# 53164                 No data   307130
# 53165                 No data   209120
# 53166  Last edited August 13.   220090
# 53167                 No data   262850
# 53168                 No data   431510
#
#                                              helpful  recommend
# 0                                     No ratings yet       True  \
# 1                                     No ratings yet       True
# 2                                     No ratings yet       True
# 3                                     No ratings yet       True
# 4                                     No ratings yet       True
# ...                                              ...        ...
# 53164  1 of 5 people (20%) found this review helpful       True
# 53165  3 of 6 people (50%) found this review helpful       True
# 53166  3 of 6 people (50%) found this review helpful       True
# 53167   0 of 1 people (0%) found this review helpful       True
# 53168  8 of 9 people (89%) found this review helpful       True
#
#                                                   review            user_id
# 0      Simple yet with great replayability. In my opi...  76561197970982479  \
# 1      Amazing, Non-stop action of blowing stuff to b...       death-hunter
# 2      Compared to Left 4 Dead 2, this game REALLY gi...           DJKamBer
# 3                                             Jogo ♥♥♥♥.          diego9031
# 4      cara nas imagens esse jogo da pouco de medo ma...  76561198081962345
# ...                                                  ...                ...
# 53164  Asteria is a fast paced indie platformer, wrap...        llDracuwulf
# 53165   Great game, awkward to get running in windows 10       ChrisCoroner
# 53166  GET THIS GAME AND CHAPTER TWO!!!!!!!!!!!!!!!!!...       MeloncraftLP
# 53167  THIS GAME!!!!!!!!!!!!!!!!!! WOOOOOOOOOOOOOOOOO...       MeloncraftLP
# 53168  Highly recommended! The storyline for shou is ...         vinquility
#
#                                                 user_url  sentiment_analysis
# 0      http://steamcommunity.com/profiles/76561197970...                   2  \
# 1              http://steamcommunity.com/id/death-hunter                   2
# 2                  http://steamcommunity.com/id/DJKamBer                   2
# 3                 http://steamcommunity.com/id/diego9031                   1
# 4      http://steamcommunity.com/profiles/76561198081...                   1
# ...                                                  ...                 ...
# 53164           http://steamcommunity.com/id/llDracuwulf                   2
# 53165          http://steamcommunity.com/id/ChrisCoroner                   0
# 53166          http://steamcommunity.com/id/MeloncraftLP                   0
# 53167          http://steamcommunity.com/id/MeloncraftLP                   0
# 53168            http://steamcommunity.com/id/vinquility                   2
#
#        ...                                app_name
# 0      ...                           Killing Floor  \
# 1      ...                           Killing Floor
# 2      ...                           Killing Floor
# 3      ...                           Killing Floor
# 4      ...                           Killing Floor
# ...    ...                                     ...
# 53164  ...                                 Asteria
# 53165  ...                 Street Fighter X Tekken
# 53166  ...           The Journey Down: Chapter One
# 53167  ...           The Journey Down: Chapter Two
# 53168  ...  Mystic Destinies: Serendipity of Aeons
#
#                                                      url release_date
# 0      http://store.steampowered.com/app/1250/Killing...   2009-05-14  \
# 1      http://store.steampowered.com/app/1250/Killing...   2009-05-14
# 2      http://store.steampowered.com/app/1250/Killing...   2009-05-14
# 3      http://store.steampowered.com/app/1250/Killing...   2009-05-14
# 4      http://store.steampowered.com/app/1250/Killing...   2009-05-14
# ...                                                  ...          ...
# 53164  http://store.steampowered.com/app/307130/Asteria/   2014-07-03
# 53165  http://store.steampowered.com/app/209120/Stree...   2012-05-11
# 53166  http://store.steampowered.com/app/220090/The_J...   2013-01-09
# 53167  http://store.steampowered.com/app/262850/The_J...   2014-08-25
# 53168  http://store.steampowered.com/app/431510/Mysti...   2016-02-11
#
#                                                     tags
# 0      ['FPS', 'Zombies', 'Co-op', 'Survival', 'Actio...  \
# 1      ['FPS', 'Zombies', 'Co-op', 'Survival', 'Actio...
# 2      ['FPS', 'Zombies', 'Co-op', 'Survival', 'Actio...
# 3      ['FPS', 'Zombies', 'Co-op', 'Survival', 'Actio...
# 4      ['FPS', 'Zombies', 'Co-op', 'Survival', 'Actio...
# ...                                                  ...
# 53164  ['Indie', 'Adventure', 'Action', 'Platformer',...
# 53165  ['Fighting', 'Action', 'Arcade', '2D Fighter',...
# 53166  ['Adventure', 'Point & Click', 'Indie', 'Comed...
# 53167  ['Adventure', 'Indie', 'Point & Click', 'Great...
# 53168  ['Visual Novel', 'Otome', 'Female Protagonist'...
#
#                                              reviews_url
# 0      http://steamcommunity.com/app/1250/reviews/?br...  \
# 1      http://steamcommunity.com/app/1250/reviews/?br...
# 2      http://steamcommunity.com/app/1250/reviews/?br...
# 3      http://steamcommunity.com/app/1250/reviews/?br...
# 4      http://steamcommunity.com/app/1250/reviews/?br...
# ...                                                  ...
# 53164  http://steamcommunity.com/app/307130/reviews/?...
# 53165  http://steamcommunity.com/app/209120/reviews/?...
# 53166  http://steamcommunity.com/app/220090/reviews/?...
# 53167  http://steamcommunity.com/app/262850/reviews/?...
# 53168  http://steamcommunity.com/app/431510/reviews/?...
#
#                                                    specs  price early_access
# 0      ['Single-player', 'Multi-player', 'Co-op', 'Cr...  19.99        False  \
# 1      ['Single-player', 'Multi-player', 'Co-op', 'Cr...  19.99        False
# 2      ['Single-player', 'Multi-player', 'Co-op', 'Cr...  19.99        False
# 3      ['Single-player', 'Multi-player', 'Co-op', 'Cr...  19.99        False
# 4      ['Single-player', 'Multi-player', 'Co-op', 'Cr...  19.99        False
# ...                                                  ...    ...          ...
# 53164  ['Single-player', 'Multi-player', 'Co-op', 'St...   4.99        False
# 53165  ['Single-player', 'Multi-player', 'Co-op', 'Sh...  29.99        False
# 53166           ['Single-player', 'Steam Trading Cards']   8.99        False
# 53167           ['Single-player', 'Steam Trading Cards']  19.99        False
# 53168  ['Single-player', 'Steam Achievements', 'Steam...   0.00        False
#
#            id             developer
# 0        1250  Tripwire Interactive
# 1        1250  Tripwire Interactive
# 2        1250  Tripwire Interactive
# 3        1250  Tripwire Interactive
# 4        1250  Tripwire Interactive
# ...       ...                   ...
# 53164  307130         Legend Studio
# 53165  209120   Capcom U.S.A., Inc.
# 53166  220090             SkyGoblin
# 53167  262850             SkyGoblin
# 53168  431510    Aeon Dream Studios
#
# [53169 rows x 22 columns]

# %% [markdown]
# Filtramos las columnas necesarias

# %%
df_usersworstdeveloper = df_usersworstdeveloper[['developer', 'posted', 'recommend', 'sentiment_analysis']]

# %%
df_usersworstdeveloper
# Out:
#                   developer                    posted  recommend
# 0      Tripwire Interactive  Posted November 5, 2011.       True  \
# 1      Tripwire Interactive    Posted March 30, 2015.       True
# 2      Tripwire Interactive     Posted July 12, 2013.       True
# 3      Tripwire Interactive   Posted August 13, 2015.       True
# 4      Tripwire Interactive     Posted April 5, 2014.       True
# ...                     ...                       ...        ...
# 53164         Legend Studio  Posted October 29, 2015.       True
# 53165   Capcom U.S.A., Inc.             Posted May 5.       True
# 53166             SkyGoblin         Posted August 13.       True
# 53167             SkyGoblin         Posted August 13.       True
# 53168    Aeon Dream Studios           Posted March 5.       True
#
#        sentiment_analysis
# 0                       2
# 1                       2
# 2                       2
# 3                       1
# 4                       1
# ...                   ...
# 53164                   2
# 53165                   0
# 53166                   0
# 53167                   0
# 53168                   2
#
# [53169 rows x 4 columns]

# %% [markdown]
# Filtramos valores 'No data'

# %%
df_usersworstdeveloper = df_usersworstdeveloper[(df_usersworstdeveloper['developer'] != 'No data')]

# %%
df_usersworstdeveloper
# Out:
#                   developer                    posted  recommend
# 0      Tripwire Interactive  Posted November 5, 2011.       True  \
# 1      Tripwire Interactive    Posted March 30, 2015.       True
# 2      Tripwire Interactive     Posted July 12, 2013.       True
# 3      Tripwire Interactive   Posted August 13, 2015.       True
# 4      Tripwire Interactive     Posted April 5, 2014.       True
# ...                     ...                       ...        ...
# 53164         Legend Studio  Posted October 29, 2015.       True
# 53165   Capcom U.S.A., Inc.             Posted May 5.       True
# 53166             SkyGoblin         Posted August 13.       True
# 53167             SkyGoblin         Posted August 13.       True
# 53168    Aeon Dream Studios           Posted March 5.       True
#
#        sentiment_analysis
# 0                       2
# 1                       2
# 2                       2
# 3                       1
# 4                       1
# ...                   ...
# 53164                   2
# 53165                   0
# 53166                   0
# 53167                   0
# 53168                   2
#
# [49602 rows x 4 columns]

# %% [markdown]
# Extraemos el año de la columna 'posted' y eliminamos aquellas filas que no tengan año (nulos). También eliminamos la columna 'posted' luego de hacer la conversión

# %%
df_usersworstdeveloper['year'] = df_usersworstdeveloper['posted'].str.extract(r'(\d{4})')

# %%
df_usersworstdeveloper.dropna(inplace=True)

# %%
df_usersworstdeveloper.drop('posted', axis=1, inplace=True)

# %%
df_usersworstdeveloper
# Out:
#                                  developer  recommend  sentiment_analysis
# 0                     Tripwire Interactive       True                   2  \
# 1                     Tripwire Interactive       True                   2
# 2                     Tripwire Interactive       True                   2
# 3                     Tripwire Interactive       True                   1
# 4                     Tripwire Interactive       True                   1
# ...                                    ...        ...                 ...
# 53160    Soloweb Studios,Ravens Eye Studio       True                   0
# 53161    Soloweb Studios,Ravens Eye Studio       True                   2
# 53162                              ShaunJS      False                   0
# 53163  Antanas Marcelionis,Renė Petrulienė       True                   2
# 53164                        Legend Studio       True                   2
#
#        year
# 0      2011
# 1      2015
# 2      2013
# 3      2015
# 4      2014
# ...     ...
# 53160  2015
# 53161  2015
# 53162  2015
# 53163  2015
# 53164  2015
#
# [41010 rows x 4 columns]

# %% [markdown]
# Convertimos la columna 'year' a entero

# %%
df_usersworstdeveloper['year'] = df_usersworstdeveloper['year'].astype(int)

# %%
df_usersworstdeveloper
# Out:
#                                  developer  recommend  sentiment_analysis
# 0                     Tripwire Interactive       True                   2  \
# 1                     Tripwire Interactive       True                   2
# 2                     Tripwire Interactive       True                   2
# 3                     Tripwire Interactive       True                   1
# 4                     Tripwire Interactive       True                   1
# ...                                    ...        ...                 ...
# 53160    Soloweb Studios,Ravens Eye Studio       True                   0
# 53161    Soloweb Studios,Ravens Eye Studio       True                   2
# 53162                              ShaunJS      False                   0
# 53163  Antanas Marcelionis,Renė Petrulienė       True                   2
# 53164                        Legend Studio       True                   2
#
#        year
# 0      2011
# 1      2015
# 2      2013
# 3      2015
# 4      2014
# ...     ...
# 53160  2015
# 53161  2015
# 53162  2015
# 53163  2015
# 53164  2015
#
# [41010 rows x 4 columns]

# %%
df = df_usersworstdeveloper

# %% [markdown]
# Filtramos los valores 'True' y las reseñas buenas o neutrales

# %%
df = df[(df['recommend'] != True)]

# %%
df = df[(df['sentiment_analysis'] != 2)]

# %%
df = df[(df['sentiment_analysis'] != 1)]

# %%
df
# Out:
#                       developer  recommend  sentiment_analysis  year
# 29         Tripwire Interactive      False                   0  2014
# 111        Tripwire Interactive      False                   0  2014
# 281        Tripwire Interactive      False                   0  2014
# 282        Tripwire Interactive      False                   0  2015
# 420                SCS Software      False                   0  2015
# ...                         ...        ...                 ...   ...
# 53078                 Alientrap      False                   0  2015
# 53115                Crian Soft      False                   0  2015
# 53117  Eric Provan - Ayyo Games      False                   0  2014
# 53127              Gaijin Games      False                   0  2013
# 53162                   ShaunJS      False                   0  2015
#
# [1887 rows x 4 columns]

# %% [markdown]
# Eliminamos las columnas 'recommend' y 'sentiment_analysis' ya que dejaron de ser necesarias

# %%
df.drop('recommend', axis=1, inplace=True)

# %%
df.drop('sentiment_analysis', axis=1, inplace=True)

# %%
df
# Out:
#                       developer  year
# 29         Tripwire Interactive  2014
# 111        Tripwire Interactive  2014
# 281        Tripwire Interactive  2014
# 282        Tripwire Interactive  2015
# 420                SCS Software  2015
# ...                         ...   ...
# 53078                 Alientrap  2015
# 53115                Crian Soft  2015
# 53117  Eric Provan - Ayyo Games  2014
# 53127              Gaijin Games  2013
# 53162                   ShaunJS  2015
#
# [1887 rows x 2 columns]

# %% [markdown]
# Utilizamos groupby para realizar un conteo de malas reseñas y creamos una nueva columna llamada 'bad_reviews'. Al finalizar eliminamos duplicados que quedaron al hacer groupby

# %%
counts = df.groupby(['developer', 'year']).size().reset_index(name='bad_reviews')

# %%
counts
# Out:
#                                              developer  year  bad_reviews
# 0                                           1C Company  2011            1
# 1                                            1C-Avalon  2015            1
# 2                                     1C: Maddox Games  2014            1
# 3    2K Australia,Gearbox Software,Aspyr (Mac and L...  2014            2
# 4    2K Australia,Gearbox Software,Aspyr (Mac and L...  2015            5
# ..                                                 ...   ...          ...
# 732                                nFusion Interactive  2015            1
# 733                                          roseVeRte  2015            1
# 734                                       storm_sharks  2015            1
# 735                                  the whale husband  2015            1
# 736                                            tobyfox  2015            4
#
# [737 rows x 3 columns]

# %% [markdown]
# Podemos notar que no hay muchas reseñas negativas, lo que podría generar empates cuando creemos la función para devolver el top 3, debemos crear un criterio de desempate. Para desempatar, crearemos la columna 'recommend_score' basandonos en la columna creada para el Dataset anterior con reseñas positivas. Entonces en caso de empate con reseñas negativas, utilizaremos la columna 'recommend_score' y aquella desarrolladora que tenga menos puntaje allí será el que vaya un puesto más arriba.

# %%
df_usersworstdeveloper
# Out:
#                                  developer  recommend  sentiment_analysis
# 0                     Tripwire Interactive       True                   2  \
# 1                     Tripwire Interactive       True                   2
# 2                     Tripwire Interactive       True                   2
# 3                     Tripwire Interactive       True                   1
# 4                     Tripwire Interactive       True                   1
# ...                                    ...        ...                 ...
# 53160    Soloweb Studios,Ravens Eye Studio       True                   0
# 53161    Soloweb Studios,Ravens Eye Studio       True                   2
# 53162                              ShaunJS      False                   0
# 53163  Antanas Marcelionis,Renė Petrulienė       True                   2
# 53164                        Legend Studio       True                   2
#
#        year
# 0      2011
# 1      2015
# 2      2013
# 3      2015
# 4      2014
# ...     ...
# 53160  2015
# 53161  2015
# 53162  2015
# 53163  2015
# 53164  2015
#
# [41010 rows x 4 columns]

# %%
df = df_usersworstdeveloper

# %%
df['bad_reviews'] = (df['recommend'] == False) & (df['sentiment_analysis'] == 0)

# %%
df['bad_reviews'] = df['bad_reviews'].astype(int)

# %%
df
# Out:
#                                  developer  recommend  sentiment_analysis
# 0                     Tripwire Interactive       True                   2  \
# 1                     Tripwire Interactive       True                   2
# 2                     Tripwire Interactive       True                   2
# 3                     Tripwire Interactive       True                   1
# 4                     Tripwire Interactive       True                   1
# ...                                    ...        ...                 ...
# 53160    Soloweb Studios,Ravens Eye Studio       True                   0
# 53161    Soloweb Studios,Ravens Eye Studio       True                   2
# 53162                              ShaunJS      False                   0
# 53163  Antanas Marcelionis,Renė Petrulienė       True                   2
# 53164                        Legend Studio       True                   2
#
#        year  bad_reviews
# 0      2011            0
# 1      2015            0
# 2      2013            0
# 3      2015            0
# 4      2014            0
# ...     ...          ...
# 53160  2015            0
# 53161  2015            0
# 53162  2015            1
# 53163  2015            0
# 53164  2015            0
#
# [41010 rows x 5 columns]

# %% [markdown]
# Creamos la columna 'recommend_score' y luego filtramos los valores indeseados

# %%
df['recommend_score'] = (df['recommend'] == True) & ((df['sentiment_analysis'] == 1) | (df['sentiment_analysis'] == 2))

# %%
df['recommend_score'] = df['recommend_score'] * df['sentiment_analysis']

# %%
df = df[~((df['recommend'] == True) & (df['sentiment_analysis'] == 0))]

# %%
df = df[~((df['recommend'] == False) & (df['sentiment_analysis'] == 1))]

# %%
df = df[~((df['recommend'] == False) & (df['sentiment_analysis'] == 2))]

# %%
df
# Out:
#                                  developer  recommend  sentiment_analysis
# 0                     Tripwire Interactive       True                   2  \
# 1                     Tripwire Interactive       True                   2
# 2                     Tripwire Interactive       True                   2
# 3                     Tripwire Interactive       True                   1
# 4                     Tripwire Interactive       True                   1
# ...                                    ...        ...                 ...
# 53159          Forever Entertainment S. A.       True                   1
# 53161    Soloweb Studios,Ravens Eye Studio       True                   2
# 53162                              ShaunJS      False                   0
# 53163  Antanas Marcelionis,Renė Petrulienė       True                   2
# 53164                        Legend Studio       True                   2
#
#        year  bad_reviews  recommend_score
# 0      2011            0                2
# 1      2015            0                2
# 2      2013            0                2
# 3      2015            0                1
# 4      2014            0                1
# ...     ...          ...              ...
# 53159  2015            0                1
# 53161  2015            0                2
# 53162  2015            1                0
# 53163  2015            0                2
# 53164  2015            0                2
#
# [32491 rows x 6 columns]

# %% [markdown]
# Eliminamos las columnas 'recommend' y 'sentiment_analysis' porque dejaron de ser necesarias

# %%
df.drop('recommend', axis=1, inplace=True)

# %%
df.drop('sentiment_analysis', axis=1, inplace=True)

# %%
df
# Out:
#                                  developer  year  bad_reviews  recommend_score
# 0                     Tripwire Interactive  2011            0                2
# 1                     Tripwire Interactive  2015            0                2
# 2                     Tripwire Interactive  2013            0                2
# 3                     Tripwire Interactive  2015            0                1
# 4                     Tripwire Interactive  2014            0                1
# ...                                    ...   ...          ...              ...
# 53159          Forever Entertainment S. A.  2015            0                1
# 53161    Soloweb Studios,Ravens Eye Studio  2015            0                2
# 53162                              ShaunJS  2015            1                0
# 53163  Antanas Marcelionis,Renė Petrulienė  2015            0                2
# 53164                        Legend Studio  2015            0                2
#
# [32491 rows x 4 columns]

# %% [markdown]
# Agrupamos

# %%
df_agrupado = df.groupby(['developer', 'year']).agg({'bad_reviews': 'sum', 'recommend_score': 'sum'}).reset_index()

# %%
df_agrupado
# Out:
#                                   developer  year  bad_reviews
# 0                            07th Expansion  2015            0  \
# 1     10th Art Studio,Adventure Productions  2015            0
# 2                            11 bit studios  2014            0
# 3                            11 bit studios  2015            0
# 4                                  14° East  2015            0
# ...                                     ...   ...          ...
# 2743                      the whale husband  2015            1
# 2744                                tobyfox  2015            4
# 2745                           varlamov5264  2015            0
# 2746       vidiludi games and entertainment  2015            0
# 2747                            高考恋爱委员会,橘子班  2015            0
#
#       recommend_score
# 0                   1
# 1                   2
# 2                  20
# 3                  30
# 4                   2
# ...               ...
# 2743               12
# 2744              167
# 2745                1
# 2746                2
# 2747                2
#
# [2748 rows x 4 columns]

# %% [markdown]
# Filtramos aquellas desarrolladoras que no tengan malas reseñas en el año especificado

# %%
df_usersworstdeveloper = df_agrupado

# %%
df_usersworstdeveloper = df_usersworstdeveloper[(df_usersworstdeveloper['bad_reviews'] != 0)]

# %%
df_usersworstdeveloper
# Out:
#                                               developer  year  bad_reviews
# 7                                            1C Company  2011            1  \
# 9                                             1C-Avalon  2015            1
# 11                                     1C: Maddox Games  2014            1
# 20    2K Australia,Gearbox Software,Aspyr (Mac and L...  2014            2
# 21    2K Australia,Gearbox Software,Aspyr (Mac and L...  2015            5
# ...                                                 ...   ...          ...
# 2730                                nFusion Interactive  2015            1
# 2735                                          roseVeRte  2015            1
# 2742                                       storm_sharks  2015            1
# 2743                                  the whale husband  2015            1
# 2744                                            tobyfox  2015            4
#
#       recommend_score
# 7                   0
# 9                   0
# 11                  6
# 20                 47
# 21                 39
# ...               ...
# 2730                0
# 2735                0
# 2742                0
# 2743               12
# 2744              167
#
# [737 rows x 4 columns]

# %% [markdown]
# Reemplazamos los valores '&amp' por '&' y guardamos el Dataframe en formato CSV

# %%
df_usersworstdeveloper['developer'] = df_usersworstdeveloper['developer'].str.replace('&amp;', '&')

# %%
df_usersworstdeveloper.to_csv('UsersWorstDeveloper.csv', index=False)

# %% [markdown]
# # sentiment_analysis

# %% [markdown]
# Importamos los Datasets que necesitaremos y merge

# %%
user_reviews = pd.read_csv('australian_user_reviews_actualizado.csv')
steam_games = pd.read_csv('output_steam_games.csv')

# %%
df_sentiment_analysis = pd.merge(user_reviews, steam_games, left_on='item_id', right_on='id')

# %%
df_sentiment_analysis
# Out:
#                                   funny                    posted
# 0                               No data  Posted November 5, 2011.  \
# 1                               No data    Posted March 30, 2015.
# 2                               No data     Posted July 12, 2013.
# 3                               No data   Posted August 13, 2015.
# 4                               No data     Posted April 5, 2014.
# ...                                 ...                       ...
# 53164                           No data  Posted October 29, 2015.
# 53165                           No data             Posted May 5.
# 53166  1 person found this review funny         Posted August 13.
# 53167                           No data         Posted August 13.
# 53168                           No data           Posted March 5.
#
#                   last_edited  item_id
# 0                     No data     1250  \
# 1                     No data     1250
# 2                     No data     1250
# 3                     No data     1250
# 4                     No data     1250
# ...                       ...      ...
# 53164                 No data   307130
# 53165                 No data   209120
# 53166  Last edited August 13.   220090
# 53167                 No data   262850
# 53168                 No data   431510
#
#                                              helpful  recommend
# 0                                     No ratings yet       True  \
# 1                                     No ratings yet       True
# 2                                     No ratings yet       True
# 3                                     No ratings yet       True
# 4                                     No ratings yet       True
# ...                                              ...        ...
# 53164  1 of 5 people (20%) found this review helpful       True
# 53165  3 of 6 people (50%) found this review helpful       True
# 53166  3 of 6 people (50%) found this review helpful       True
# 53167   0 of 1 people (0%) found this review helpful       True
# 53168  8 of 9 people (89%) found this review helpful       True
#
#                                                   review            user_id
# 0      Simple yet with great replayability. In my opi...  76561197970982479  \
# 1      Amazing, Non-stop action of blowing stuff to b...       death-hunter
# 2      Compared to Left 4 Dead 2, this game REALLY gi...           DJKamBer
# 3                                             Jogo ♥♥♥♥.          diego9031
# 4      cara nas imagens esse jogo da pouco de medo ma...  76561198081962345
# ...                                                  ...                ...
# 53164  Asteria is a fast paced indie platformer, wrap...        llDracuwulf
# 53165   Great game, awkward to get running in windows 10       ChrisCoroner
# 53166  GET THIS GAME AND CHAPTER TWO!!!!!!!!!!!!!!!!!...       MeloncraftLP
# 53167  THIS GAME!!!!!!!!!!!!!!!!!! WOOOOOOOOOOOOOOOOO...       MeloncraftLP
# 53168  Highly recommended! The storyline for shou is ...         vinquility
#
#                                                 user_url  sentiment_analysis
# 0      http://steamcommunity.com/profiles/76561197970...                   2  \
# 1              http://steamcommunity.com/id/death-hunter                   2
# 2                  http://steamcommunity.com/id/DJKamBer                   2
# 3                 http://steamcommunity.com/id/diego9031                   1
# 4      http://steamcommunity.com/profiles/76561198081...                   1
# ...                                                  ...                 ...
# 53164           http://steamcommunity.com/id/llDracuwulf                   2
# 53165          http://steamcommunity.com/id/ChrisCoroner                   0
# 53166          http://steamcommunity.com/id/MeloncraftLP                   0
# 53167          http://steamcommunity.com/id/MeloncraftLP                   0
# 53168            http://steamcommunity.com/id/vinquility                   2
#
#        ...                                app_name
# 0      ...                           Killing Floor  \
# 1      ...                           Killing Floor
# 2      ...                           Killing Floor
# 3      ...                           Killing Floor
# 4      ...                           Killing Floor
# ...    ...                                     ...
# 53164  ...                                 Asteria
# 53165  ...                 Street Fighter X Tekken
# 53166  ...           The Journey Down: Chapter One
# 53167  ...           The Journey Down: Chapter Two
# 53168  ...  Mystic Destinies: Serendipity of Aeons
#
#                                                      url release_date
# 0      http://store.steampowered.com/app/1250/Killing...   2009-05-14  \
# 1      http://store.steampowered.com/app/1250/Killing...   2009-05-14
# 2      http://store.steampowered.com/app/1250/Killing...   2009-05-14
# 3      http://store.steampowered.com/app/1250/Killing...   2009-05-14
# 4      http://store.steampowered.com/app/1250/Killing...   2009-05-14
# ...                                                  ...          ...
# 53164  http://store.steampowered.com/app/307130/Asteria/   2014-07-03
# 53165  http://store.steampowered.com/app/209120/Stree...   2012-05-11
# 53166  http://store.steampowered.com/app/220090/The_J...   2013-01-09
# 53167  http://store.steampowered.com/app/262850/The_J...   2014-08-25
# 53168  http://store.steampowered.com/app/431510/Mysti...   2016-02-11
#
#                                                     tags
# 0      ['FPS', 'Zombies', 'Co-op', 'Survival', 'Actio...  \
# 1      ['FPS', 'Zombies', 'Co-op', 'Survival', 'Actio...
# 2      ['FPS', 'Zombies', 'Co-op', 'Survival', 'Actio...
# 3      ['FPS', 'Zombies', 'Co-op', 'Survival', 'Actio...
# 4      ['FPS', 'Zombies', 'Co-op', 'Survival', 'Actio...
# ...                                                  ...
# 53164  ['Indie', 'Adventure', 'Action', 'Platformer',...
# 53165  ['Fighting', 'Action', 'Arcade', '2D Fighter',...
# 53166  ['Adventure', 'Point & Click', 'Indie', 'Comed...
# 53167  ['Adventure', 'Indie', 'Point & Click', 'Great...
# 53168  ['Visual Novel', 'Otome', 'Female Protagonist'...
#
#                                              reviews_url
# 0      http://steamcommunity.com/app/1250/reviews/?br...  \
# 1      http://steamcommunity.com/app/1250/reviews/?br...
# 2      http://steamcommunity.com/app/1250/reviews/?br...
# 3      http://steamcommunity.com/app/1250/reviews/?br...
# 4      http://steamcommunity.com/app/1250/reviews/?br...
# ...                                                  ...
# 53164  http://steamcommunity.com/app/307130/reviews/?...
# 53165  http://steamcommunity.com/app/209120/reviews/?...
# 53166  http://steamcommunity.com/app/220090/reviews/?...
# 53167  http://steamcommunity.com/app/262850/reviews/?...
# 53168  http://steamcommunity.com/app/431510/reviews/?...
#
#                                                    specs  price early_access
# 0      ['Single-player', 'Multi-player', 'Co-op', 'Cr...  19.99        False  \
# 1      ['Single-player', 'Multi-player', 'Co-op', 'Cr...  19.99        False
# 2      ['Single-player', 'Multi-player', 'Co-op', 'Cr...  19.99        False
# 3      ['Single-player', 'Multi-player', 'Co-op', 'Cr...  19.99        False
# 4      ['Single-player', 'Multi-player', 'Co-op', 'Cr...  19.99        False
# ...                                                  ...    ...          ...
# 53164  ['Single-player', 'Multi-player', 'Co-op', 'St...   4.99        False
# 53165  ['Single-player', 'Multi-player', 'Co-op', 'Sh...  29.99        False
# 53166           ['Single-player', 'Steam Trading Cards']   8.99        False
# 53167           ['Single-player', 'Steam Trading Cards']  19.99        False
# 53168  ['Single-player', 'Steam Achievements', 'Steam...   0.00        False
#
#            id             developer
# 0        1250  Tripwire Interactive
# 1        1250  Tripwire Interactive
# 2        1250  Tripwire Interactive
# 3        1250  Tripwire Interactive
# 4        1250  Tripwire Interactive
# ...       ...                   ...
# 53164  307130         Legend Studio
# 53165  209120   Capcom U.S.A., Inc.
# 53166  220090             SkyGoblin
# 53167  262850             SkyGoblin
# 53168  431510    Aeon Dream Studios
#
# [53169 rows x 22 columns]

# %% [markdown]
# Filtramos las columnas de interes

# %%
df_sentiment_analysis = df_sentiment_analysis[['developer', 'sentiment_analysis']]

# %%
df_sentiment_analysis
# Out:
#                   developer  sentiment_analysis
# 0      Tripwire Interactive                   2
# 1      Tripwire Interactive                   2
# 2      Tripwire Interactive                   2
# 3      Tripwire Interactive                   1
# 4      Tripwire Interactive                   1
# ...                     ...                 ...
# 53164         Legend Studio                   2
# 53165   Capcom U.S.A., Inc.                   0
# 53166             SkyGoblin                   0
# 53167             SkyGoblin                   0
# 53168    Aeon Dream Studios                   2
#
# [53169 rows x 2 columns]

# %% [markdown]
# Filtramos valores 'No data'

# %%
df_sentiment_analysis = df_sentiment_analysis[(df_sentiment_analysis['developer'] != 'No data')]

# %%
df_sentiment_analysis
# Out:
#                   developer  sentiment_analysis
# 0      Tripwire Interactive                   2
# 1      Tripwire Interactive                   2
# 2      Tripwire Interactive                   2
# 3      Tripwire Interactive                   1
# 4      Tripwire Interactive                   1
# ...                     ...                 ...
# 53164         Legend Studio                   2
# 53165   Capcom U.S.A., Inc.                   0
# 53166             SkyGoblin                   0
# 53167             SkyGoblin                   0
# 53168    Aeon Dream Studios                   2
#
# [49602 rows x 2 columns]

# %% [markdown]
# Creamos columnas con conteo de reseñas por tipo (buenas, neutrales o malas)

# %%
df_sentiment_analysis['good_reviews'] = (df_sentiment_analysis['sentiment_analysis'] == 2).astype(int)
df_sentiment_analysis['neutral_reviews'] = (df_sentiment_analysis['sentiment_analysis'] == 1).astype(int)
df_sentiment_analysis['bad_reviews'] = (df_sentiment_analysis['sentiment_analysis'] == 0).astype(int)

# %% [markdown]
# Agrupamos y sumamos los conteos

# %%
result_df = df_sentiment_analysis.groupby('developer').agg({'good_reviews': 'sum', 'neutral_reviews': 'sum', 'bad_reviews': 'sum'}).reset_index()

# %%
result_df
# Out:
#                                   developer  good_reviews  neutral_reviews
# 0                            07th Expansion             0                2  \
# 1     10th Art Studio,Adventure Productions             1                1
# 2                                10tons Ltd             1                0
# 3                            11 bit studios            30               10
# 4                                  14° East             1                0
# ...                                     ...           ...              ...
# 2103                            xXarabongXx             1                0
# 2104                       △○□× (Miwashiba)             5                0
# 2105                               インレ,Inre             1                3
# 2106                                    橘子班             1                2
# 2107                            高考恋爱委员会,橘子班             1                1
#
#       bad_reviews
# 0               1
# 1               0
# 2               0
# 3              22
# 4               1
# ...           ...
# 2103            0
# 2104            0
# 2105            1
# 2106            1
# 2107            0
#
# [2108 rows x 4 columns]

# %%
df_sentiment_analysis = result_df

# %% [markdown]
# Reemplazamos valores '&amp' por '&' en la columna developer

# %%
df_sentiment_analysis['developer'] = df_sentiment_analysis['developer'].str.replace('&amp;', '&')

# %% [markdown]
# Guardamos el Dataframe en formato CSV

# %%
df_sentiment_analysis.to_csv('sentiment_analysis.csv', index=False)
